# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

font = {'size'   : 12}

plt.rc('font', **font)

# %%
us_df = pd.read_csv('Data/time_series_covid_19_confirmed_US.csv')
us_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3261 entries, 0 to 3260
# Columns: 130 entries, UID to 5/19/20
# dtypes: float64(3), int64(121), object(6)
# memory usage: 3.2+ MB

# %%
# us_df.head()

# %%
# us_df.Province_State.unique()

# %% [markdown]
# ## For Texas

# %%
texas_df = us_df[us_df['Province_State']=='Texas']
texas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 256 entries, 2528 to 3244
# Columns: 130 entries, UID to 5/19/20
# dtypes: float64(3), int64(121), object(6)
# memory usage: 262.0+ KB

# %%
# texas_df

# %%
texas_df = texas_df.drop(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region',
                         'Lat', 'Long_', 'Combined_Key'], axis=1)
# texas_df

# %%
tx_data = texas_df.sum(axis = 0, skipna = True) 
# tx_data

# %%
final_data = pd.DataFrame({'Date': texas_df.columns, 'Confirmed': tx_data})
# final_data

# %%
## Find the increase amount in each day
final_data['Increase'] =  final_data['Confirmed'] - final_data['Confirmed'].shift(1)
# final_data.head()

# %%
final_data['Moving_Average'] = final_data.Increase.rolling(window=7).mean()
# final_data

# %%
texas_data = final_data
texas_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119 entries, 1/22/20 to 5/19/20
# Data columns (total 4 columns):
# Date              119 non-null object
# Confirmed         119 non-null int64
# Increase          118 non-null float64
# Moving_Average    112 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 9.6+ KB

# %%
plt.figure(figsize=(20,10))
plt.bar(final_data['Date'], final_data['Increase'], color="dodgerblue", width=0.25, label = 'Confirmed Cases')
plt.plot(final_data['Date'], final_data['Moving_Average'], color="red", linewidth=5, label = '7-days moving average')
plt.xlabel('', fontsize=18)
plt.ylabel('# of Confirmed Cases', fontsize=18)
plt.title('TEXAS')
plt.xlim('3/11/20', '5/20/20')
plt.xticks(rotation=70)
plt.axvspan('3/23/20', '4/30/20', alpha=0.1, color='red')
plt.axvspan('4/30/20', '5/20/20', alpha=0.1, color='green')
plt.legend(loc='upper left', fancybox=True, framealpha=1, shadow=True, borderpad=1)
# plt.savefig('plots/Texas_reopen.png')
plt.show()

# %% [markdown]
# ## For North Dakota

# %%
texas_df = us_df[us_df['Province_State']=='North Dakota']
texas_df.info()
texas_df = texas_df.drop(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region',
                         'Lat', 'Long_', 'Combined_Key'], axis=1)
# texas_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 1995 to 3235
# Columns: 130 entries, UID to 5/19/20
# dtypes: float64(3), int64(121), object(6)
# memory usage: 56.3+ KB

# %%
tx_data = texas_df.sum(axis = 0, skipna = True)

# %%
final_data = pd.DataFrame({'Date': texas_df.columns, 'Confirmed': tx_data})
## Find the increase amount in each day
final_data['Increase'] =  final_data['Confirmed'] - final_data['Confirmed'].shift(1)

# %%
final_data['Moving_Average'] = final_data.Increase.rolling(window=5).mean()
# final_data

# %%
dakota_data = final_data
dakota_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119 entries, 1/22/20 to 5/19/20
# Data columns (total 4 columns):
# Date              119 non-null object
# Confirmed         119 non-null int64
# Increase          118 non-null float64
# Moving_Average    114 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.6+ KB

# %%
plt.figure(figsize=(20,10))
plt.bar(final_data['Date'], final_data['Increase'], color="dodgerblue", width=0.25, label = 'Confirmed Cases')
plt.plot(final_data['Date'], final_data['Moving_Average'], color="red", linewidth=5, label = '7-days moving average')
plt.xlabel('', fontsize=18)
plt.ylabel('# of Confirmed Cases', fontsize=18)
plt.title('North Dakota')
plt.xlim('3/11/20', '5/20/20')
plt.xticks(rotation=70)
plt.axvspan('4/10/20', '5/1/20', alpha=0.1, color='red')
plt.axvspan('5/1/20', '5/20/20', alpha=0.1, color='green')
plt.legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1)
# plt.savefig('plots/NorthDakota_reopen.png')
plt.show()

# %% [markdown]
# ## For New Jersey

# %%
texas_df = us_df[us_df['Province_State']=='New Jersey']
texas_df.info()
texas_df = texas_df.drop(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region',
                         'Lat', 'Long_', 'Combined_Key'], axis=1)
# texas_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 1779 to 3231
# Columns: 130 entries, UID to 5/19/20
# dtypes: float64(3), int64(121), object(6)
# memory usage: 23.5+ KB

# %%
tx_data = texas_df.sum(axis = 0, skipna = True)

# %%
final_data = pd.DataFrame({'Date': texas_df.columns, 'Confirmed': tx_data})
## Find the increase amount in each day
final_data['Increase'] =  final_data['Confirmed'] - final_data['Confirmed'].shift(1)

# %%
final_data['Moving_Average'] = final_data.Increase.rolling(window=7).mean()
# final_data

# %%
jersey_data = final_data
jersey_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119 entries, 1/22/20 to 5/19/20
# Data columns (total 4 columns):
# Date              119 non-null object
# Confirmed         119 non-null int64
# Increase          118 non-null float64
# Moving_Average    112 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.6+ KB

# %%
plt.figure(figsize=(20,10))
plt.bar(final_data['Date'], final_data['Increase'], color="dodgerblue", width=0.25, label = 'Confirmed Cases')
plt.plot(final_data['Date'], final_data['Moving_Average'], color="red", linewidth=5, label = '7-days moving average')
plt.xlabel('', fontsize=18)
plt.ylabel('# of Confirmed Cases', fontsize=18)
plt.title('New Jersey')
plt.xlim('3/11/20', '5/20/20')
plt.xticks(rotation=70)
plt.axvspan('3/21/20', '5/20/20', alpha=0.1, color='red')
# plt.axvspan('5/1/20', '5/20/20', alpha=0.1, color='green')
plt.legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1)
# plt.savefig('plots/NewJersey_reopen.png')
plt.show()

# %% [markdown]
# ## For New York

# %%
texas_df = us_df[us_df['Province_State']=='New York']
texas_df.info()
texas_df = texas_df.drop(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region',
                         'Lat', 'Long_', 'Combined_Key'], axis=1)
# texas_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1833 to 3233
# Columns: 130 entries, UID to 5/19/20
# dtypes: float64(3), int64(121), object(6)
# memory usage: 65.5+ KB

# %%
tx_data = texas_df.sum(axis = 0, skipna = True)

# %%
final_data = pd.DataFrame({'Date': texas_df.columns, 'Confirmed': tx_data})
## Find the increase amount in each day
final_data['Increase'] =  final_data['Confirmed'] - final_data['Confirmed'].shift(1)

# %%
final_data['Moving_Average'] = final_data.Increase.rolling(window=7).mean()
# final_data

# %%
newyork_data = final_data
newyork_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119 entries, 1/22/20 to 5/19/20
# Data columns (total 4 columns):
# Date              119 non-null object
# Confirmed         119 non-null int64
# Increase          118 non-null float64
# Moving_Average    112 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.6+ KB

# %%
plt.figure(figsize=(20,10))
plt.bar(final_data['Date'], final_data['Increase'], color="dodgerblue", width=0.25, label = 'Confirmed Cases')
plt.plot(final_data['Date'], final_data['Moving_Average'], color="red", linewidth=5, label = '7-days moving average')
plt.xlabel('', fontsize=18)
plt.ylabel('# of Confirmed Cases', fontsize=18)
plt.title('New York')
plt.xlim('3/11/20', '5/20/20')
plt.xticks(rotation=70)
plt.axvspan('3/22/20', '5/20/20', alpha=0.1, color='red')
# plt.axvspan('5/1/20', '5/20/20', alpha=0.1, color='green')
plt.legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1)
# plt.savefig('plots/NewYork_reopen.png')
plt.show()

# %% [markdown]
# ## Combined Plot

# %%
font = {'size'   : 12}

plt.rc('font', **font)


plt.figure(figsize=(20,40))


plt.subplot(4,1,1)
plt.bar(texas_data['Date'], texas_data['Increase'], color="dodgerblue", width=0.25, label = 'Confirmed Cases')
plt.plot(texas_data['Date'], texas_data['Moving_Average'], color="red", linewidth=5, label = '7-days moving average')
plt.xlabel('', fontsize=18)
plt.ylabel('# of Confirmed Cases', fontsize=28)
plt.title('(a) TEXAS', fontsize = 30)
plt.xlim('3/11/20', '5/20/20')
plt.xticks(rotation=70)
plt.axvspan('3/23/20', '4/30/20', alpha=0.1, color='red')
plt.axvspan('4/30/20', '5/20/20', alpha=0.1, color='green')
plt.legend(loc='upper left', fancybox=True, framealpha=1, shadow=True, borderpad=1, fontsize=16)
plt.subplots_adjust(wspace=0.2, hspace=0.25)




## Dakota
plt.subplot(4,1,2)
plt.bar(dakota_data['Date'], dakota_data['Increase'], color="dodgerblue", width=0.25, label = 'Confirmed Cases')
plt.plot(dakota_data['Date'], dakota_data['Moving_Average'], color="red", linewidth=5, label = '7-days moving average')
plt.xlabel('', fontsize=18)
plt.ylabel('# of Confirmed Cases', fontsize=28)
plt.title('(b) North Dakota', fontsize = 30)
plt.xlim('3/11/20', '5/20/20')
plt.xticks(rotation=70)
plt.axvspan('4/10/20', '5/1/20', alpha=0.1, color='red')
plt.axvspan('5/1/20', '5/20/20', alpha=0.1, color='green')
plt.legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1, fontsize=16)
plt.subplots_adjust(wspace=0.2, hspace=0.25)

## jersey
plt.subplot(4,1,3)
plt.bar(jersey_data['Date'], jersey_data['Increase'], color="dodgerblue", width=0.25, label = 'Confirmed Cases')
plt.plot(jersey_data['Date'], jersey_data['Moving_Average'], color="red", linewidth=5, label = '7-days moving average')
plt.xlabel('', fontsize=18)
plt.ylabel('# of Confirmed Cases', fontsize=28)
plt.title('(c) New Jersey', fontsize = 30)
plt.xlim('3/11/20', '5/20/20')
plt.xticks(rotation=70)
plt.axvspan('3/21/20', '5/20/20', alpha=0.1, color='red')
# plt.axvspan('5/1/20', '5/20/20', alpha=0.1, color='green')
plt.legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1, fontsize=16)
plt.subplots_adjust(wspace=0.2, hspace=0.25)

## New york

plt.subplot(4,1,4)
plt.bar(newyork_data['Date'], newyork_data['Increase'], color="dodgerblue", width=0.25, label = 'Confirmed Cases')
plt.plot(newyork_data['Date'], newyork_data['Moving_Average'], color="red", linewidth=5, label = '7-days moving average')
plt.xlabel('', fontsize=18)
plt.ylabel('# of Confirmed Cases', fontsize=28)
plt.title('(d) New York', fontsize = 30)
plt.xlim('3/11/20', '5/20/20')
plt.xticks(rotation=70)
plt.axvspan('3/22/20', '5/20/20', alpha=0.1, color='red')
# plt.axvspan('5/1/20', '5/20/20', alpha=0.1, color='green')
plt.legend(loc='upper left',fancybox=True, framealpha=1, shadow=True, borderpad=1, fontsize=16)
plt.subplots_adjust(wspace=0.2, hspace=0.25)

# plt.savefig('plots/reopen.png')
plt.show()
